# %%
import glob
import pandas as pd
file_name = "C:\\Users\\505\\Desktop\\양진이\\상가업소_201512\\상가업소_201512_01.csv"
df = pd.read_csv(file_name , engine="python");
df = df[["시도명","시군구명","상호명"]][df.상호명.notnull() & df.상호명.str.contains("스타벅스")]
df["종류"] = "스타벅스"
count_df = df.groupby(["시도명", "시군구명"]).count()


file_name2 = "C:\\Users\\505\\Desktop\\양진이\\상가업소_201512\\상가업소_201512_01.csv"
df2 = pd.read_csv(file_name , engine="python");
df2 = df2[["시도명","시군구명","상호명"]][df2.상호명.notnull() & df2.상호명.str.contains("스타벅스")]
df2["종류"] = "스타벅스"
count_df = df2.groupby(["시도명", "시군구명"]).count()

# %%
count_file_name =

# %%
df = pd.read_csv("C:\\git\\python_data__visual\\final_projet\\refineData_2015.csv" , engine="python");
df.head()
# Out:
#      시도명 시군구명  상호명
# 0  서울특별시  강남구   49
# 1  서울특별시  강동구    8
# 2  서울특별시  강북구    5
# 3  서울특별시  강서구    7
# 4  서울특별시  관악구    6

# %%
df2 = pd.read_csv("C:\\git\\python_data__visual\\final_projet\\refineData_2016.csv" , engine="python");
df2.head()
# Out:
#      시도명 시군구명  상호명
# 0  서울특별시  강남구   56
# 1  서울특별시  강동구    8
# 2  서울특별시  강북구    4
# 3  서울특별시  강서구    6
# 4  서울특별시  관악구    6

# %%
result_df = df.merge(df2, how="outer", on=['시도명', '시군구명'])

# %%
result_df
# Out:
#       시도명  시군구명  상호명_x  상호명_y
# 0   서울특별시   강남구     49     56
# 1   서울특별시   강동구      8      8
# 2   서울특별시   강북구      5      4
# 3   서울특별시   강서구      7      6
# 4   서울특별시   관악구      6      6
# 5   서울특별시   광진구     11     13
# 6   서울특별시   구로구      7      8
# 7   서울특별시   금천구      6      6
# 8   서울특별시   노원구      6      7
# 9   서울특별시   도봉구      1      1
# 10  서울특별시  동대문구      6      6
# 11  서울특별시   동작구      3      3
# 12  서울특별시   마포구     18     17
# 13  서울특별시  서대문구     16     14
# 14  서울특별시   서초구     30     34
# 15  서울특별시   성동구      3      3
# 16  서울특별시   성북구     10     12
# 17  서울특별시   송파구     16     16
# 18  서울특별시   양천구      8      6
# 19  서울특별시  영등포구     17     18
# 20  서울특별시   용산구      8     10
# 21  서울특별시   은평구      5      7
# 22  서울특별시   종로구     26     25
# 23  서울특별시    중구     33     28
# 24  서울특별시   중랑구      5      5

# %%
refined_data_dirs = "C:\\git\\python_data__visual\\final_projet\\"


def mergeResultDataOnlySeoul(dir) :
    file_list = glob.glob(dir + "refineData*.csv");
    is_start = True;
    for file_name in file_list :
        if is_start  == True:
            result_df = pd.read_csv(file_name , engine="python");
            is_start = False;
        else :
            df = pd.read_csv(file_name, engine="python")
            result_df = result_df.merge(df, how="outer", on=['시도명', '시군구명'])
    result_df.to_csv("final_result.csv")

mergeResultDataOnlySeoul(refined_data_dirs)

# %%
# !final_result.csv

# %%
import matplotlib.pyplot as plt
refined_data_dirs = "C:\\git\\python_data__visual\\final_projet\\final_result.csv"
def showGraph(file_name) :
    df = pd.read_csv(refined_data_dirs, engine="python");
    df.plot(kind="bar", title=df.시군구명)
    plt.show()

# %%
showGraph(refined_data_dirs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-f48e7b058c94> in <module>()
# ----> 1 showGraph(refined_data_dirs)
#
# <ipython-input-124-cb95b080c502> in showGraph(file_name)
#       3 def showGraph(file_name) :
#       4     df = pd.read_csv(refined_data_dirs, engine="python");
# ----> 5     df.plot(kind="bar", title=df.시군구명)
#       6     plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
# -> 1694     plot_obj.generate()
#    1695     plot_obj.draw()
#    1696     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     246         self._add_table()
#     247         self._make_legend()
# --> 248         self._adorn_subplots()
#     249
#     250         for ax in self.axes:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _adorn_subplots(self)
#     418             ax.grid(self.grid)
#     419
# --> 420         if self.title:
#     421             if self.subplots:
#     422                 if is_list_like(self.title):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#     953         raise ValueError("The truth value of a {0} is ambiguous. "
#     954                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 955                          .format(self.__class__.__name__))
#     956
#     957     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
def set_font_config() :
    font_location = "c:\\windows\\fonts\\malgun.ttf"
    font_name = font_manager.FontProperties(fname=font_location).get_name()
    matplotlib.rc('font', family=font_name)
set_font_config()

# %%
def showIncreasingGrpah(filename):
    df = pd.read_csv(filename, engine="python");
    inc_rate_dic = {
        "시군구명": [],
        "rate": []
    }
    for i in range(len(df)):
        cur = df.iloc[i];

        inc_rate_dic["시군구명"].append(cur.시군구명);
        inc_rate_dic["rate"].append((cur["2017"] / cur["2016"])*100);
    result_df = pd.DataFrame(inc_rate_dic)
    result_df.index = df.시군구명;
    result_df.plot(kind="barh", title='스타벅스');
    plt.show()
    #result_df.to_csv("result_incresing.csv")

showIncreasingGrpah(refined_data_dirs);

# %%
refined_data_dirs = "C:\\git\\python_data__visual\\final_projet\\final_result.csv"

df = pd.read_csv(refined_data_dirs, engine="python")
df = df[["시도명", "시군구명" , "2015", "2016" , "2017"]]
df.index = df.시군구명
df.plot(kind="bar", title='스타벅스')
plt.show()

# %%
df
# Out:
#       Unnamed: 0    시도명  시군구명  2015  2016  2017
# 시군구명
# 강남구            0  서울특별시   강남구    49    56    70
# 강동구            1  서울특별시   강동구     8     8    10
# 강북구            2  서울특별시   강북구     5     4     5
# 강서구            3  서울특별시   강서구     7     6    14
# 관악구            4  서울특별시   관악구     6     6     9
# 광진구            5  서울특별시   광진구    11    13    14
# 구로구            6  서울특별시   구로구     7     8    10
# 금천구            7  서울특별시   금천구     6     6     9
# 노원구            8  서울특별시   노원구     6     7     7
# 도봉구            9  서울특별시   도봉구     1     1     1
# 동대문구          10  서울특별시  동대문구     6     6     8
# 동작구           11  서울특별시   동작구     3     3     5
# 마포구           12  서울특별시   마포구    18    17    26
# 서대문구          13  서울특별시  서대문구    16    14    16
# 서초구           14  서울특별시   서초구    30    34    41
# 성동구           15  서울특별시   성동구     3     3     5
# 성북구           16  서울특별시   성북구    10    12    14
# 송파구           17  서울특별시   송파구    16    16    24
# 양천구           18  서울특별시   양천구     8     6     8
# 영등포구          19  서울특별시  영등포구    17    18    26
# 용산구           20  서울특별시   용산구     8    10    14
# 은평구           21  서울특별시   은평구     5     7     9
# 종로구           22  서울특별시   종로구    26    25    27
# 중구            23  서울특별시    중구    33    28    42
# 중랑구           24  서울특별시   중랑구     5     5     6
